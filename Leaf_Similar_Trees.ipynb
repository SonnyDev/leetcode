# %% [markdown]
# <a href="https://colab.research.google.com/github/SonnyDev/leetcode/blob/main/Leaf_Similar_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem
#
# Consider all the leaves of a binary tree, from left to right order, the values of those leaves form a leaf value sequence.
#
# ![image.png](data:image/png;base64,...)
#
# For example, in the given tree above, the leaf value sequence is (6, 7, 4, 9, 8).
#
# Two binary trees are considered leaf-similar if their leaf value sequence is the same.
#
# Return true if and only if the two given trees with head nodes root1 and root2 are leaf-similar.
#
#
#
# Example 1:
#
# ![image.png](data:image/png;base64,...)
# Input: root1 = [3,5,1,6,2,9,8,null,null,7,4], root2 = [3,5,1,6,7,4,2,null,null,null,null,null,null,9,8]
#
# Output: true
#
# Example 2:
#
# ![image.png](data:image/png;base64,...)
# Input: root1 = [1,2,3], root2 = [1,3,2]
#
# Output: false
#
#
# Constraints:
#
# The number of nodes in each tree will be in the range [1, 200].
#
# Both of the given trees will have values in the range [0, 200].

# %% [markdown]
# ## Solution
#
# To solve the problem of determining whether two binary trees are leaf-similar, we can follow these steps:
#
# * Traverse each tree to collect their leaf sequences: Use a depth-first search (DFS) or a breadth-first search (BFS) to traverse each tree and collect the values of the leaves. Since we need to compare the sequences of leaf values, it's important to maintain the order of leaves as they appear from left to right.
#
# * Compare the leaf sequences: Once you have both leaf sequences, compare them. If they are identical, return true; otherwise, return false.

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def leafSimilar(root1, root2):
    def dfs(node):
        if not node:
            return []
        if not node.left and not node.right:
            return [node.val]
        return dfs(node.left) + dfs(node.right)

    return dfs(root1) == dfs(root2)

# Example usage
# Construct the binary trees from the Example 1
# Tree 1
root1 = TreeNode(3)
root1.left = TreeNode(5)
root1.right = TreeNode(1)
root1.left.left = TreeNode(6)
root1.left.right = TreeNode(2)
root1.left.right.left = TreeNode(7)
root1.left.right.right = TreeNode(4)
root1.right.left = TreeNode(9)
root1.right.right = TreeNode(8)

# Tree 2
root2 = TreeNode(3)
root2.left = TreeNode(5)
root2.right = TreeNode(1)
root2.left.left = TreeNode(6)
root2.left.right = TreeNode(7)
root2.right.left = TreeNode(4)
root2.right.right = TreeNode(2)
root2.right.right.left = TreeNode(9)
root2.right.right.right = TreeNode(8)

# Check if the two trees are leaf-similar
print(leafSimilar(root1, root2))
# Out:
# True
